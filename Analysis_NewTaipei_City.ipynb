# %%
import pandas as pd

df = pd.read_csv('./data/real_estate_raw_NewTaipei_City.csv')
df.columns = ['鄉鎮市區',
              '交易標的',
              '土地區段位置建物區段門牌',
              '土地移轉總面積平方公尺',
              '都市土地使用分區',
              '非都市土地使用分區',
              '非都市土地使用編定',
              '交易年月日',
              '交易筆棟數',
              '移轉層次',
              '總樓層數',
              '建物型態',
              '主要用途',
              '主要建材',
              '建築完成年月',
              '建物移轉總面積平方公尺',
              '建物現況格局-房',
              '建物現況格局-廳',
              '建物現況格局-衛',
              '建物現況格局-隔間',
              '有無管理組織',
              '總價元',
              '單價元平方公尺',
              '車位類別',
              '車位移轉總面積平方公尺',
              '車位總價元',
              '備註',
              '編號',
              '主建物面積',
              '附屬建物面積',
              '陽台面積',
              '電梯']

print(df.dtypes)
print(df.shape)

# 找出'單價元平方公尺'的缺失值為'僅車位交易'
print(df.isnull().sum())
print(df[df['單價元平方公尺'].isnull()])

# 刪除'單價元平方公尺'中包含'僅車位交易'的欄位
a = df[~df['單價元平方公尺'].isnull()]
print(a.shape)

# 針對'建物型態'檢查是否有異常值或需重新分類-->看起來不需要處理
print(a['建物型態'])

# 針對'都市土地使用分區'檢查是否有異常值或需重新分類
print(a[a['都市土地使用分區'].isnull()])

# 用subset方法刪除'都市土地使用分區'為缺失值的行
b = a.dropna(subset = ['都市土地使用分區'])

# 針對'主要用途'檢查是否有異常值或需重新分類 -->看起來是對應到'交易標的'單純只有交易'土地'的欄位
print(b['主要用途'].head(50)) 
print(b[b['主要用途'].isnull()])
c = b.dropna(subset = ['主要用途'])
print(c)

# 將資料依鄉鎮市區進行排序
d = c.sort_values(by = '鄉鎮市區', ascending = True)
print(d.dtypes)


# '總價元'及'建物移轉總面積平方公尺'欄位的describe值(並將工程數字轉化格式為普通數字)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
print(d[['單價元平方公尺', '建物移轉總面積平方公尺']].describe())

# 計算均價(按'鄉鎮市區)
d.groupby('鄉鎮市區').agg({'總價元': 'mean'})




# d.to_csv('./data/real_estate_raw_NewTaipei_City_cleaned.csv', index = 0, header = 1, encoding = 'utf-8')
# Out:
# 鄉鎮市區             object
# 交易標的             object
# 土地區段位置建物區段門牌     object
# 土地移轉總面積平方公尺     float64
# 都市土地使用分區         object
# 非都市土地使用分區        object
# 非都市土地使用編定        object
# 交易年月日             int64
# 交易筆棟數            object
# 移轉層次             object
# 總樓層數             object
# 建物型態             object
# 主要用途             object
# 主要建材             object
# 建築完成年月          float64
# 建物移轉總面積平方公尺     float64
# 建物現況格局-房          int64
# 建物現況格局-廳          int64
# 建物現況格局-衛          int64
# 建物現況格局-隔間        object
# 有無管理組織           object
# 總價元               int64
# 單價元平方公尺         float64
# 車位類別             object
# 車位移轉總面積平方公尺     float64
# 車位總價元             int64
# 備註               object
# 編號               object
# 主建物面積           float64
# 附屬建物面積          float64
# 陽台面積            float64
# 電梯               object
# dtype: object
# (98897, 32)
# 鄉鎮市區                0
# 交易標的                0
# 土地區段位置建物區段門牌        0
# 土地移轉總面積平方公尺         0
# 都市土地使用分區         8219
# 非都市土地使用分區       92785
# 非都市土地使用編定       92818
# 交易年月日               0
# 交易筆棟數               0
# 移轉層次            11862
# 總樓層數            11858
# 建物型態                0
# 主要用途            11882
# 主要建材            11856
# 建築完成年月          14052
# 建物移轉總面積平方公尺         0
# 建物現況格局-房            0
# 建物現況格局-廳            0
# 建物現況格局-衛            0
# 建物現況格局-隔間           0
# 有無管理組織              0
# 總價元                 0
# 單價元平方公尺          2353
# 車位類別            49664
# 車位移轉總面積平方公尺         0
# 車位總價元               0
# 備註              35252
# 編號                  0
# 主建物面積               0
# 附屬建物面積              0
# 陽台面積                0
# 電梯                  3
# dtype: int64
#       鄉鎮市區 交易標的                                       土地區段位置建物區段門牌  \
# 62     中和區   車位                                  新北市中和區安平路５５號等公共設施
# 66     新莊區   車位                          新北市新莊區民安西路３７０至３９２（雙）號地下二層
# 172    新店區   車位                                       新北市新店區中央路３６號
# 300    板橋區   車位                                       新北市板橋區萬板路３６號
# 319    新店區   車位                                    新北市新店區寶橋路８５巷５０號
# ...    ...  ...                                                ...
# 98108  中和區   車位                                 新北市中和區中原五街５５號二十三樓等
# 98144  土城區   車位  新北市土城區學府路一段１２２、１２２之１之２之３之４、１２４、１２４之１之２之３之４、１２２...
# 98294  林口區   車位                                   新北市林口區松柏路１１０號二樓等
# 98385  中和區   車位                                      新北市中和區連城路６８號等
# 98386  新店區   車位                                   新北市新店區安興路１１５號二樓等
#
#        土地移轉總面積平方公尺 都市土地使用分區 非都市土地使用分區 非都市土地使用編定    交易年月日      交易筆棟數  移轉層次  \
# 62            3.76        住       NaN       NaN  1111227  土地1建物1車位1   NaN
# 66            0.13        住       NaN       NaN  1111224  土地1建物1車位1  地下二層
# 172           2.00        住       NaN       NaN  1111226  土地1建物1車位1    一層
# 300           1.25        住       NaN       NaN  1110216  土地1建物0車位1   NaN
# 319           1.28        住       NaN       NaN  1101227  土地1建物1車位1    一層
# ...            ...      ...       ...       ...      ...        ...   ...
# 98108         2.26        住       NaN       NaN  1131021  土地1建物1車位3   NaN
# 98144         0.00      NaN       NaN       NaN  1130930  土地0建物1車位1   NaN
# 98294         0.35        住       NaN       NaN  1130809  土地1建物1車位1   NaN
# 98385         1.84        住       NaN       NaN  1130429  土地1建物1車位1   NaN
# 98386         2.07        商       NaN       NaN  1130415  土地6建物1車位1   NaN
#
#        ... 單價元平方公尺  車位類別 車位移轉總面積平方公尺    車位總價元  \
# 62     ...     NaN  坡道平面       62.61  3500000
# 66     ...     NaN  坡道平面       32.95  1250000
# 172    ...     NaN  坡道平面       34.99  1900000
# 300    ...     NaN  坡道平面       40.73  2500000
# 319    ...     NaN  坡道平面       27.25  2500000
# ...    ...     ...   ...         ...      ...
# 98108  ...     NaN  坡道平面      100.86  6500000
# 98144  ...     NaN  坡道平面       37.15  2200000
# 98294  ...     NaN  坡道平面       32.24  1600000
# 98385  ...     NaN  坡道平面       41.77  2400000
# 98386  ...     NaN  坡道平面       16.02  1800000
#
#                                                       備註                   編號  \
# 62                                         本案為子母車位僅車位交易；  RPWOMLLJLHIGFHF58DA
# 66                                                僅車位交易；  RPOOMLMJLHIGFBF37EA
# 172                                               僅車位交易；  RPQNMLTJLHIGFCF28EA
# 300                                               僅車位交易；  RPTOMLSKKHIGFAF28DA
# 319                                               僅車位交易；  RPPNMLRKKHIGFCF87DA
# ...                                                  ...                  ...
# 98108  93號車位價格230萬元整；94號及95號車位價格各210萬元整親友、員工、共有人或其他特殊...  RPTNMLTJKIJGFHF09DA
# 98144                             建物坐落地號：學成段785地號；僅車位交易；  RPQNMLMLJIJGFAF47DA
# 98294                                             僅車位交易；  RPPOMLQLRHJGFBF68DA
# 98385                                             僅車位交易；  RPPNMLNKKIJGFHF18DA
# 98386                                             僅車位交易；  RPVNMLMKKIJGFCF18DA
#
#        主建物面積  附屬建物面積  陽台面積 電梯
# 62       0.0     0.0   0.0  有
# 66       0.0     0.0   0.0  有
# 172      0.0     0.0   0.0  有
# 300      0.0     0.0   0.0  有
# 319      0.0     0.0   0.0  有
# ...      ...     ...   ... ..
# 98108    0.0     0.0   0.0  有
# 98144    0.0     0.0   0.0  有
# 98294    0.0     0.0   0.0  有
# 98385    0.0     0.0   0.0  有
# 98386    0.0     0.0   0.0  有
#
# [2353 rows x 32 columns]
# (96544, 32)
# 0                    透天厝
# 1        住宅大樓(11層含以上有電梯)
# 2           公寓(5樓含以下無電梯)
# 3                    透天厝
# 4        住宅大樓(11層含以上有電梯)
#               ...
# 98892    住宅大樓(11層含以上有電梯)
# 98893    住宅大樓(11層含以上有電梯)
# 98894    住宅大樓(11層含以上有電梯)
# 98895    住宅大樓(11層含以上有電梯)
# 98896                透天厝
# Name: 建物型態, Length: 96544, dtype: object
#       鄉鎮市區          交易標的        土地區段位置建物區段門牌  土地移轉總面積平方公尺 都市土地使用分區 非都市土地使用分區  \
# 9      三峽區            土地      白雞段紫微小段416-7地號     14336.00      NaN    山坡地保育區
# 14     瑞芳區     房地(土地+建物)        新北市瑞芳區大埔路３５號        22.91      NaN       鄉村區
# 19     淡水區     房地(土地+建物)        新北市淡水區樹林口７２號       201.16      NaN    山坡地保育區
# 38     泰山區            土地        泰山段一小段18-2地號      3089.00      NaN     一般農業區
# 39     新莊區     房地(土地+建物)        新北市新莊區五權二路６號      1154.97      NaN       工業區
# ...    ...           ...                 ...          ...      ...       ...
# 98349  瑞芳區     房地(土地+建物)  新北市瑞芳區瑞濱路１４７之１５號二樓        48.00      NaN    山坡地保育區
# 98361  新店區  房地(土地+建物)+車位  新北市新店區中央路１８７號十一樓之１        26.83      NaN       NaN
# 98369  樹林區            土地           西園段1545地號       495.45      NaN     一般農業區
# 98405  三峽區            土地      麥子園段劉厝埔小段148地號       209.60      NaN     一般農業區
# 98896  新店區            建物      新北市新店區秀岡三街２８６號         0.00      NaN       NaN
#
#       非都市土地使用編定    交易年月日       交易筆棟數 移轉層次  ...   單價元平方公尺  車位類別 車位移轉總面積平方公尺  \
# 9          林業用地  1111231  土地10建物0車位0  NaN  ...    1360.0   NaN        0.00
# 14       乙種建築用地  1111209   土地1建物1車位0    全  ...   16442.0   NaN        0.00
# 19       丙種建築用地  1111221   土地1建物1車位0    全  ...   87949.0   NaN        0.00
# 38         農牧用地  1111205   土地1建物0車位0  NaN  ...   85305.0   NaN        0.00
# 39       丁種建築用地  1111228   土地1建物1車位0    全  ...  622074.0   NaN        0.00
# ...         ...      ...         ...  ...  ...       ...   ...         ...
# 98349    丙種建築用地  1130716   土地2建物1車位0   二層  ...   70160.0   NaN        0.00
# 98361       NaN  1130616   土地3建物1車位1  十一層  ...  227810.0  坡道平面       25.97
# 98369      農牧用地  1130530   土地1建物0車位0  NaN  ...   22686.0   NaN        0.00
# 98405      農牧用地  1130221   土地1建物0車位0  NaN  ...   63502.0   NaN        0.00
# 98896       NaN  1070108   土地0建物1車位0    全  ...   84138.0   NaN        0.00
#
#          車位總價元                         備註                   編號   主建物面積  \
# 9            0                        NaN  RPSNMLMLKHIGFIF38DA    0.00
# 14           0      親友、員工、共有人或其他特殊關係間之交易；  RPRNMLMLKHIGFFF08EA   27.52
# 19           0                        NaN  RPPNMLOLKHIGFEF97EA  248.33
# 38           0                        NaN  RPXQMLTJKHIGFBF98DA    0.00
# 39           0                      其他增建；  RPWPMLRLKIHGFBF78DA  555.00
# ...        ...                        ...                  ...     ...
# 98349        0                      頂樓加蓋；  RPTNMLQKKIJGFFF68DA   45.61
# 98361  2500000                        NaN  RPVOMLSKJIJGFCF78DA   85.55
# 98369        0                        NaN  RPWNMLTJKIJGFIF86DA    0.00
# 98405        0                        NaN  RPTNMLTLIIJGFIF56DA    0.00
# 98896        0  僅建物之交易。；建物坐落地號：秀岡一段3-2地號；  RPROMLNKKIJGFCF97DA  261.84
#
#        附屬建物面積   陽台面積 電梯
# 9        0.00   0.00  無
# 14       1.44   1.44  無
# 19       0.00  18.87  有
# 38       0.00   0.00  無
# 39      49.43   0.00  無
# ...       ...    ... ..
# 98349    0.00   0.00  無
# 98361    3.00   6.06  有
# 98369    0.00   0.00  無
# 98405    0.00   0.00  無
# 98896    0.00  24.69  無
#
# [7709 rows x 32 columns]
# 0     住家用
# 1     住家用
# 2     住家用
# 3     住家用
# 4     住家用
# 5     住家用
# 6     商業用
# 7     住家用
# 8     住家用
# 10    住家用
# 11    住家用
# 12    住家用
# 13    住家用
# 15    住家用
# 16    住家用
# 17    住家用
# 18    住家用
# 20    住家用
# 21    住家用
# 22    住家用
# 23    工業用
# 24    住家用
# 25    住家用
# 26    住家用
# 27    住家用
# 28    住家用
# 29    住家用
# 30    住家用
# 31    辦公用
# 32    NaN
# 33    住家用
# 34    住家用
# 35    商業用
# 36    住家用
# 37    工業用
# 41    住家用
# 42    住家用
# 43    住家用
# 44    住家用
# 45    住家用
# 46    住家用
# 47    住家用
# 48    住家用
# 49    住家用
# 50    工業用
# 51    住家用
# 52    住家用
# 53    商業用
# 54    工業用
# 55    住家用
# Name: 主要用途, dtype: object
#       鄉鎮市區 交易標的 土地區段位置建物區段門牌  土地移轉總面積平方公尺    都市土地使用分區 非都市土地使用分區 非都市土地使用編定  \
# 32     新店區   土地   櫻花段303-3地號       304.77           住       NaN       NaN
# 88     金山區   土地    文化段1046地號       167.70           住       NaN       NaN
# 89     金山區   土地    文化段1046地號       167.70           住       NaN       NaN
# 90     金山區   土地    文化段1046地號       377.32           住       NaN       NaN
# 91     金山區   土地    文化段1046地號       167.70           住       NaN       NaN
# ...    ...  ...          ...          ...         ...       ...       ...
# 98282  新莊區   土地   豐年段157-1地號        17.53  都市：其他:道路用地       NaN       NaN
# 98356  林口區   土地     瑞平段543地號       753.10   都市：其他:保護區       NaN       NaN
# 98366  汐止區   土地     大同段3-2地號       109.87   都市：其他:保護區       NaN       NaN
# 98378  板橋區   土地      光環段28地號       136.96           住       NaN       NaN
# 98415  樹林區   土地    文林段1374地號        20.31  都市：其他:道路用地       NaN       NaN
#
#          交易年月日      交易筆棟數 移轉層次  ...   單價元平方公尺 車位類別 車位移轉總面積平方公尺 車位總價元  \
# 32     1111210  土地2建物0車位0  NaN  ...   29859.0  NaN         0.0     0
# 88     1111205  土地1建物0車位0  NaN  ...   33274.0  NaN         0.0     0
# 89     1111202  土地1建物0車位0  NaN  ...   33274.0  NaN         0.0     0
# 90     1111206  土地1建物0車位0  NaN  ...   33274.0  NaN         0.0     0
# 91     1111202  土地1建物0車位0  NaN  ...   33274.0  NaN         0.0     0
# ...        ...        ...  ...  ...       ...  ...         ...   ...
# 98282  1130828  土地1建物0車位0  NaN  ...  139760.0  NaN         0.0     0
# 98356  1130618  土地1建物0車位0  NaN  ...    6957.0  NaN         0.0     0
# 98366  1130514  土地1建物0車位0  NaN  ...    9075.0  NaN         0.0     0
# 98378  1130410  土地1建物0車位0  NaN  ...  332750.0  NaN         0.0     0
# 98415  1130104  土地2建物0車位0  NaN  ...   29542.0  NaN         0.0     0
#
#                                      備註                   編號  主建物面積  附屬建物面積  \
# 32                                  NaN  RPQPMLSKJHIGFCF18DA    0.0     0.0
# 88                                  NaN  RPVNMLNLKIHGFDF28DA    0.0     0.0
# 89                                  NaN  RPXNMLNLKIHGFDF48DA    0.0     0.0
# 90                                  NaN  RPROMLNLKIHGFDF97DA    0.0     0.0
# 91                                  NaN  RPSOMLNLKIHGFDF08DA    0.0     0.0
# ...                                 ...                  ...    ...     ...
# 98282                      包含公共設施保留地用地；  RPPNMLKKKIJGFBF37EA    0.0     0.0
# 98356                               NaN  RPUOMLLKKIJGFBF97DA    0.0     0.0
# 98366                               NaN  RPRNMLQJKIJGFDF18DA    0.0     0.0
# 98378  本案依土地法13條之一相關規定處分，相關辦理程序費用由買方負擔。  RPUNMLSKIIJGFAF28DA    0.0     0.0
# 98415                               NaN  RPPNMLQKKIJGFIF68EA    0.0     0.0
#
#        陽台面積 電梯
# 32      0.0  無
# 88      0.0  無
# 89      0.0  無
# 90      0.0  無
# 91      0.0  無
# ...     ... ..
# 98282   0.0  無
# 98356   0.0  無
# 98366   0.0  無
# 98378   0.0  無
# 98415   0.0  無
#
# [7408 rows x 32 columns]
#       鄉鎮市區          交易標的          土地區段位置建物區段門牌  土地移轉總面積平方公尺 都市土地使用分區  \
# 0      八里區  房地(土地+建物)+車位        新北市八里區忠孝路１８之３號       100.15        住
# 1      淡水區  房地(土地+建物)+車位   新北市淡水區新市二路一段１２６號十五樓        10.72        住
# 2      三重區     房地(土地+建物)       新北市三重區碧華街２８９號四樓        30.00        住
# 3      三重區     房地(土地+建物)       新北市三重區仁興街１１巷１６號        52.14        住
# 4      蘆洲區  房地(土地+建物)+車位      新北市蘆洲區長興路１７８號十一樓        39.39        住
# ...    ...           ...                   ...          ...      ...
# 98891  土城區  房地(土地+建物)+車位    新北市土城區青雲路４１１巷３號十一樓        22.33        住
# 98892  淡水區  房地(土地+建物)+車位  新北市淡水區中正東路二段１０７巷８號八樓        38.03        住
# 98893  土城區  房地(土地+建物)+車位      新北市土城區青雲路４０５號十二樓        14.23        住
# 98894  土城區  房地(土地+建物)+車位       新北市土城區青雲路３９９號三樓        19.32        住
# 98895  土城區  房地(土地+建物)+車位       新北市土城區青雲路４０１號六樓        19.80        住
#
#       非都市土地使用分區 非都市土地使用編定    交易年月日      交易筆棟數   移轉層次  ...   單價元平方公尺  車位類別  \
# 0           NaN       NaN  1111226  土地1建物1車位1      全  ...   79825.0    其他
# 1           NaN       NaN  1111227  土地1建物1車位1    十五層  ...   68636.0  坡道平面
# 2           NaN       NaN  1111231  土地1建物1車位0  四層，陽台  ...  108108.0   NaN
# 3           NaN       NaN  1111221  土地1建物1車位0      全  ...  112019.0   NaN
# 4           NaN       NaN  1111221  土地1建物1車位2    十一層  ...  131402.0  坡道平面
# ...         ...       ...      ...        ...    ...  ...       ...   ...
# 98891       NaN       NaN  1090322  土地1建物1車位1    十一層  ...   96267.0  坡道平面
# 98892       NaN       NaN  1090122  土地1建物1車位1     八層  ...  107252.0  坡道平面
# 98893       NaN       NaN  1081123  土地1建物1車位1    十二層  ...   95325.0  坡道平面
# 98894       NaN       NaN  1080914  土地1建物1車位1     三層  ...   87050.0  坡道平面
# 98895       NaN       NaN  1080915  土地1建物1車位1     六層  ...   89500.0  坡道平面
#
#       車位移轉總面積平方公尺    車位總價元                                                 備註  \
# 0            0.00        0                                                NaN
# 1           37.86  1400000                                                NaN
# 2            0.00        0                         親友、員工、共有人或其他特殊關係間之交易；頂樓加蓋；
# 3            0.00        0                         親友、員工、共有人或其他特殊關係間之交易；頂樓加蓋；
# 4           50.42        0                                                NaN
# ...           ...      ...                                                ...
# 98891       33.32  2200000                                  預售屋、或土地及建物分件登記案件；
# 98892       38.20  1850000                                  預售屋、或土地及建物分件登記案件；
# 98893       33.32  1900000  1.房屋價格新台幣3300000元2.土地價格新台幣4570000元3.於113年8月14日...
# 98894       33.32  1800000                                  預售屋、或土地及建物分件登記案件；
# 98895       33.32  1900000  1.房屋價格新台幣4320000元2.土地價格新台幣5960000元3.於113年8月14日...
#
#                         編號   主建物面積  附屬建物面積   陽台面積 電梯
# 0      RPWNMLSJKHIGFEF78DA  153.83   55.38  29.97  無
# 1      RPUOMLNLKHIGFEF38DA   31.92    3.80   5.25  有
# 2      RPXNMLMLKHIGFGF68DA   74.00    0.00   0.00  無
# 3      RPROMLMLKHIGFGF18DA   66.06    0.00   0.00  無
# 4      RPUNMLNLKHIGFGF48DA  120.56    6.82  13.90  有
# ...                    ...     ...     ...    ... ..
# 98891  RPUPMLOJKIJGFAF18DA   72.82    4.07  11.24  有
# 98892  RPSPMLKKKIJGFEF08DA   67.65   10.13   6.26  有
# 98893  RPWOMLPJJIJGFAF28DA   49.58    3.17   3.38  有
# 98894  RPWOMLOJKIJGFAF28DA   63.82    7.12   5.29  有
# 98895  RPRPMLOJJIJGFAF77DA   67.52    6.52   4.04  有
#
# [81427 rows x 32 columns]
# 鄉鎮市區             object
# 交易標的             object
# 土地區段位置建物區段門牌     object
# 土地移轉總面積平方公尺     float64
# 都市土地使用分區         object
# 非都市土地使用分區        object
# 非都市土地使用編定        object
# 交易年月日             int64
# 交易筆棟數            object
# 移轉層次             object
# 總樓層數             object
# 建物型態             object
# 主要用途             object
# 主要建材             object
# 建築完成年月          float64
# 建物移轉總面積平方公尺     float64
# 建物現況格局-房          int64
# 建物現況格局-廳          int64
# 建物現況格局-衛          int64
# 建物現況格局-隔間        object
# 有無管理組織           object
# 總價元               int64
# 單價元平方公尺         float64
# 車位類別             object
# 車位移轉總面積平方公尺     float64
# 車位總價元             int64
# 備註               object
# 編號               object
# 主建物面積           float64
# 附屬建物面積          float64
# 陽台面積            float64
# 電梯               object
# dtype: object
#             單價元平方公尺  建物移轉總面積平方公尺
# count   81427.00000  81427.00000
# mean   132394.13550    131.77077
# std     48305.04396    139.12490
# min         0.00000      0.11000
# 25%     99013.00000     85.70000
# 50%    129772.00000    115.20000
# 75%    160089.50000    152.25000
# max   1368180.00000  19410.49000
#                 總價元
# 鄉鎮市區
# 三峽區  14056478.84124
# 三芝區   4639455.44218
# 三重區  17155662.67156
# 中和區  18456470.33134
# 五股區  13128608.93066
# 八里區  10748028.56977
# 土城區  15340429.43786
# 坪林區  15766666.66667
# 平溪區   8700000.00000
# 新店區  19700942.78457
# 新莊區  19087796.41771
# 板橋區  17805079.21036
# 林口區  18235775.58080
# 樹林區  15824563.94258
# 永和區  17140118.45810
# 汐止區  15340364.13156
# 泰山區  14449192.35684
# 淡水區  11070597.31855
# 深坑區  13402726.18079
# 烏來區   4476666.66667
# 瑞芳區   5543825.68571
# 石碇區   8350000.00000
# 石門區   1931724.13793
# 萬里區   5552608.42742
# 蘆洲區  16110751.16552
# 貢寮區   5080343.93103
# 金山區   7504537.45912
# 雙溪區   3206666.66667
# 鶯歌區  11801775.81843
