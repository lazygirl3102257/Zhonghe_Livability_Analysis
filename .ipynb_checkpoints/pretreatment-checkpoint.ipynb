# %%
import pandas as pd
df = pd.read_csv('./data/NewTaipei_City_important_landmark_raw.csv', encoding = 'utf-8')
print(df.head())
print(df.shape)

# 篩選出中和區的地標
a = df[df['行政區'].isin(['中和區'])]
print(a)

# 按地標類型排序
b = a.sort_values(by = '地標類型', ascending = True)
print(b['地標類型'])

# 保留'地標類型'為'大專院校','高中職','國民中學','國民小學'的欄位
College = b[b['地標類型'].str.contains('大專院校')]
print(College)
Senior_High_Schools = b[b['地標類型'].str.contains('高中職')]
print(Senior_High_Schools)
Junior_High_Schools = b[b['地標類型'].str.contains('國民中學')]
print(Junior_High_Schools)
Elementary_Schools = b[b['地標類型'].str.contains('國民小學')]
print(Elementary_Schools)

# 將各級學校欄位合成一個csv檔
pd_concat = pd.concat([College, Senior_High_Schools, Junior_High_Schools, Elementary_Schools], ignore_index = False)
print(pd_concat)

# pd_concat.to_csv('./data/Schools_cleaned.csv', index = 0, header = 1, encoding = 'utf-8')


# 載入超市csv檔
market = pd.read_csv('./data/新北市公有市場及超市清冊.csv', encoding = 'utf-8')
print(market)
# 篩選出中和區
Zhonghe_market = market[market['address'].str.contains('新北市中和區')]
print(Zhonghe_market)

# 將好市多，全聯，家樂福，大潤發位於中和的門市據點列出
Costco = {
    'name': '好市多',
    'phone': '02-449-9909',
    'address': '新北市中和區中山路二段347號'
}
RT_Marts = {
    'name': ['大潤發中和店', '大潤發景平店'],
    'phone': ['02-82411111', '02-29436000'],
    'address': ['新北市中和區中山路二段228號B2', '新北市中和區景平路182號B1']
  }
Carrefour_Markets = {
    'name': ['家樂福中和店', '家樂福景安店', '家樂福中和中山店', '家樂福中和民治店', '家樂福中和復興店', '家樂福中和圓通店', '家樂福中和壽德店', '家樂福中和興南店'],
    'phone': ['02-8245-5566', '02-2240-9628', '02-8221-2870', '02-8221-8517、02-8221-8597', '02-8242-3945', '02-2249-8224、02-2249-7404', '02-2964-3543、02-2964-3541', '02-2948-1240~1'],
    'address': ['新北市中和區中山路二段295號B1', '新北市中和區景平路353號B1', '新北市中和區中山路三段1-3號', '新北市中和區民治街120號', '新北市中和區復興路268號', '新北市中和區圓通路274號', '新北市中和區壽德街20號1樓', '新北市中和區興南路一段20號B1'],
    'types': ['量販店', '24H超市', '24H超市', '24H超市', '24H超市', '量販店', '量販店', '24H超市']
}
PX_Mart = {
    'name': ['全聯中和新生店', '全聯中和秀朗店', '全聯南華店', '全聯中和光華店', '全聯中和中山店', '全聯中和景平店', '全聯中和大勇店', '全聯中和福祥店', '全聯中和民德店', '全聯中和南山店', '全聯中和南勢角店', '全聯中和華夏店', '全聯中和安邦店', '全聯中和華新店', '全聯中和捷運店', '全聯中和景德店', '全聯中和中正店', '全聯中和宜安店', '全聯中和景新店', '全聯中和民樂店'],
    'phone': ['02-22267175', '02-29466606', '02-22482639', '02-82455860', '02-82267105', '02-82451916', '02-29495972', '02-22430586', '02-29620320', '02-22400572', '02-29401270', '02-29401736', '02-22400796', '02-29400755', '02-22401799', '02-29400696', '02-22401061', '02-22310375', '02-31518633', '02-22289128'],
    'address': ['新北市中和區新生街255、257號', '新北市中和區秀朗路３段175巷2號', '新北市中和區南華路２７號Ｂ１', '新北市中和區光華街31巷2號1樓', '新北市中和區中山路３段35-2號', '新北市中和區景平路541號B1、543號1樓、B1', '新北市中和區大勇街78號', '新北市中和區福祥路72號', '新北市中和區民德路187號', '新北市中和區南山路146巷1號1樓', '新北市中和區捷運路29.31.33.35號', '新北市中和區工專路26號2樓、28、30號1-2樓', '新北市中和區安邦街18號1-2樓', '新北市中和區華新街26-1號1樓、26-2號B1', '新北市中和區中山路二段269號B1', '新北市中和區景德街7號、9號1樓', '新北市中和區中正路80號1樓', '新北市中和區安平路109號', '新北市中和區景新街516號地下2樓', '新北市中和區民樂路3號']
}
NanKang_Market = {
    'name': '南崁聯福利中心-民德店',
    'phone': '02-29506251',
    'address': '新北市中和區民德路176號'
}

# 將以上dict資料轉為DataFrame後，再加到超市.csv中
Costco_df = pd.DataFrame(Costco, index = [0])
print(Costco_df)
RT_Mart_df = pd.DataFrame.from_dict(RT_Marts)
print(RT_Mart_df)
Carrefour_Markets_df = pd.DataFrame.from_dict(Carrefour_Markets)
print(Carrefour_Markets_df)
PX_Mart_df = pd.DataFrame(PX_Mart)
print(PX_Mart_df)
NanKang_Market_df = pd.DataFrame(NanKang_Market, index = [0])
print(NanKang_Market_df)

Other_markets_added = pd.concat([Zhonghe_market, Costco_df, RT_Mart_df, Carrefour_Markets_df, PX_Mart_df, NanKang_Market_df], ignore_index = False)
Other_markets_added

# 填補空值
Other_markets_added_fillna = Other_markets_added.fillna({'county': '新北市', 'countycode': 65000.0, 'town': '中和區', 'areacode': 65000030.0})
Other_markets_added_fillna.reset_index(inplace = True)
print(Other_markets_added_fillna.shape)

# 超市geocoding

import googlemaps
import time
'''
gmaps = googlemaps.Client(key = 'AIzaSyC1GM-GfvCeTE3z2Suzvam13Fufo-D3prc')

To_list = Other_markets_added_fillna['address'].tolist()

address = To_list

ids = []
for addr in address:
    geocode_result = gmaps.geocode(addr)
    loc = geocode_result[0]['geometry']['location']
    time.sleep(0.1)
    print(loc)
'''    
markets_geocoding = pd.read_csv('./data/超市地址經緯度.csv', encoding = 'utf-8')
markets_geocoding.reset_index(inplace = True)
markets_geocoding.rename(columns = {'index': 'Lat', 'Markets_geocoding': 'Lng'}, inplace = True)


# 將Lat欄提取出Series並整理前綴詞
lat_column = pd.Series(markets_geocoding['Lat'])
tidy_lat = lat_column.str.replace("{'lat': ", "")

# 將Lng欄提取出Series並整理前綴詞和後綴符號
lng_column = pd.Series(markets_geocoding['Lng'])
tidy_lng1 = lng_column.str.replace("'lng': ","")
tidy_lng2 = tidy_lng1.str.rstrip('}')

geocoding_2columns = pd.concat([tidy_lat, tidy_lng2], axis = 1, ignore_index = False)
geocoding_2columns

# 將'經緯度完整資料'欄位加進去
markets = pd.read_csv('./data/超市地址經緯度.csv', sep = '{', encoding = 'utf-8')
markets.reset_index(drop = True)
markets.rename(columns = {'Markets_geocoding': 'geometry'}, inplace = True)

geometry = pd.Series(markets['geometry'])
geometry_done = geometry.str.rstrip('}')
done = geometry_done.reset_index(drop = True)

all_geometry = pd.concat([geocoding_2columns, done], axis = 1, ignore_index = False)
all_geometry

# 將經緯度資料加回超市清冊中

merged_geocoding = pd.concat([Other_markets_added_fillna, all_geometry], axis = 1, ignore_index = False)
print(merged_geocoding.shape)

# 刪除'index'和'item'欄
cleaned = merged_geocoding.drop(columns = ['index', 'item'], axis = 1, inplace = False)
cleaned.shape

# cleaned.to_csv('./data/Zhonghe_markets_cleaned.csv', header = 1, encoding = 'utf-8')

# 載入公園csv檔
parks = pd.read_csv('./data/新北市公園.csv',index_col = 'no', encoding = 'utf-8')
print(parks)

# 篩選出中和區境內的公園
filtered_park = parks[parks['area'].isin(['中和區'])]
print(filtered_park)
print(filtered_park.shape)

# 將address欄前面加上'新北市中和區'字串
filtered_park['address'] = '新北市中和區' + filtered_park['address']
filtered_park.reset_index(inplace = True)
print(filtered_park)

# 用dotenv將api key隱藏在系統變數中
from dotenv import load_dotenv
load_dotenv()
import os
load_key = os.environ.get('GOOGLE_MAP_API_Key')

'''
# 公園geocoding
gmaps = googlemaps.Client(key = load_key)

To_list = filtered_park['address'].tolist()
address = To_list

ids = []
for addr in address:
    geocode_result = gmaps.geocode(addr)
    loc = geocode_result[0]['geometry']['location']
    time.sleep(0.1)
    print(loc)
'''
park_geocoding = pd.read_csv('./data/新北市公園經緯度.csv', encoding = 'utf-8')
park_geocoding.reset_index(inplace = True)
park_geocoding.rename(columns = {'index': 'Lat', '新北市公園經緯度': 'Lng'}, inplace = True)

# 將Lat欄提取出Series並整理前綴詞
park_lat_columns = pd.Series(park_geocoding['Lat'])
tidy_park_lat = park_lat_columns.str.replace("{'lat': ", "")

# 將Lng欄提取出Series並整理前綴詞和後綴符號
park_lng_columns = pd.Series(park_geocoding['Lng'])
tidy_park_lng1 = park_lng_columns.str.replace("'lng': ", "")
tidy_park_lng2 = tidy_park_lng1.str.rstrip('}')

park_geocoding_2columns = pd.concat([tidy_park_lat, tidy_park_lng2], axis = 1, ignore_index = False)
park_geocoding_2columns

# 將'經緯度完整資料'欄位加進去
park_geo = pd.read_csv('./data/新北市公園經緯度.csv', sep = '{', encoding = 'utf-8')
park_geo.reset_index(inplace = True)
park_geo.rename(columns = {'新北市公園經緯度': 'geometry'}, inplace = True)

park_geometry = pd.Series(park_geo['geometry'])
park_geometry_done = park_geometry.str.rstrip('}')
done2 = park_geometry_done.reset_index(drop = True)
done2

# 將經緯度資料加回去csv中
park_geo_done = pd.concat([filtered_park, park_geocoding_2columns, done2], axis = 1, ignore_index = False)
park_geo_done

# park_geo_done.to_csv('./data/park_cleaned.csv', header = 1, encoding = 'utf-8')
# Out:
#    objectid  行政區  地標類型              地標名稱                    地址           電話  \
# 0         1  三芝區  大專院校           私立馬偕醫學院   新北市三芝區古庄里1鄰中正路三段46號  02-26360303
# 1         2  三芝區  大專院校  私立馬偕醫護管理專科學校三芝校區   新北市三芝區古庄里1鄰中正路三段42號  02-26366799
# 2         3  三峽區  大專院校        國立臺北大學三峽校區   新北市三峽區龍恩里23鄰大學路151號  02-26748189
# 3         4  土城區  大專院校        私立宏國德霖科技大學  新北市土城區清化里1鄰青雲路380巷1號  02-22733567
# 4         5  中和區  大專院校          私立華夏科技大學   新北市中和區華新里44鄰工專路111號  02-89415100
#
#     網址    twd97_x     twd97_y                        更新日期
# 0  NaN  300033.79  2793883.34  2024-12-26 09:28:17.233000
# 1  NaN  300191.93  2793604.77  2024-12-26 09:28:17.233000
# 2  NaN  287682.93  2759752.50  2024-12-26 09:28:17.233000
# 3  NaN  296082.43  2762923.08  2024-12-26 09:28:17.233000
# 4  NaN  301259.57  2763722.47  2024-12-26 09:28:17.233000
# (1967, 10)
#       objectid  行政區   地標類型             地標名稱                      地址  \
# 4            5  中和區   大專院校         私立華夏科技大學     新北市中和區華新里44鄰工專路111號
# 30          31  中和區     公所            中和區公所    新北市中和區漳和里3鄰景平路634-2號
# 61          62  中和區  戶政事務所     新北市中和戶政事務所本所    新北市中和區外南里2鄰南山路236號4樓
# 62          63  中和區  戶政事務所  新北市中和戶政事務所民享辦事處  新北市中和區民有里22鄰民享街37號2樓之1
# 63          64  中和區  戶政事務所  新北市中和戶政事務所員山辦事處   新北市中和區員富里4鄰中正路1163號3樓
# ...        ...  ...    ...              ...                     ...
# 1770      1771  中和區   警察機關   新北市政府警察局保安警察大隊        新北市中和區中正路1167號2樓
# 1771      1772  中和區   警察機關    新北市政府警察局婦幼警察隊        新北市中和區中正路1167號8樓
# 1772      1773  中和區   警察機關        新北市警察訓練中心           新北市中和區民安街150號
# 1773      1774  中和區   警察機關            積穗派出所           新北市中和區員山路471號
# 1774      1775  中和區   警察機關            錦和派出所            新北市中和區安邦街20號
#
#                電話                              網址    twd97_x     twd97_y  \
# 4     02-89415100                             NaN  301259.57  2763722.47
# 30    02-22482688                             NaN  300545.42  2765707.00
# 61    02-29495759  www.zhonghe.ris.ca.ntpc.gov.tw  301147.44  2764736.82
# 62    02-22263186  www.zhonghe.ris.ca.ntpc.gov.tw  297855.03  2766270.50
# 63    02-22259730  www.zhonghe.ris.ca.ntpc.gov.tw  298612.16  2766869.38
# ...           ...                             ...        ...         ...
# 1770  02-22252620      www.spc.police.ntpc.gov.tw  298569.00  2766892.00
# 1771  02-22286032      www.wpb.police.ntpc.gov.tw  298565.00  2766887.00
# 1772  02-22211890          www.police.ntpc.gov.tw  298088.00  2765666.00
# 1773  02-22268955  www.zhonghe.police.ntpc.gov.tw  298477.00  2766383.00
# 1774  02-22482551  www.zhonghe.police.ntpc.gov.tw  300072.00  2765610.00
#
#                             更新日期
# 4     2024-12-26 09:28:17.233000
# 30    2024-12-26 09:28:17.233000
# 61    2024-12-26 09:28:17.233000
# 62    2024-12-26 09:28:17.233000
# 63    2024-12-26 09:28:17.233000
# ...                          ...
# 1770  2024-12-26 09:28:17.233000
# 1771  2024-12-26 09:28:17.233000
# 1772  2024-12-26 09:28:17.233000
# 1773  2024-12-26 09:28:17.233000
# 1774  2024-12-26 09:28:17.233000
#
# [111 rows x 10 columns]
# 30          公所
# 866       國民中學
# 868       國民中學
# 867       國民中學
# 869       國民中學
#          ...
# 1244    避難收容處所
# 1708      醫學中心
# 237       防災公園
# 238       防災公園
# 587        高中職
# Name: 地標類型, Length: 111, dtype: object
#    objectid  行政區  地標類型      地標名稱                   地址           電話   網址  \
# 4         5  中和區  大專院校  私立華夏科技大學  新北市中和區華新里44鄰工專路111號  02-89415100  NaN
#
#      twd97_x     twd97_y                        更新日期
# 4  301259.57  2763722.47  2024-12-26 09:28:17.233000
#      objectid  行政區 地標類型    地標名稱                   地址           電話   網址  \
# 587       588  中和區  高中職  市立中和高中  新北市中和區嘉慶里14鄰連城路460號  02-22227146  NaN
#
#        twd97_x     twd97_y                        更新日期
# 587  298286.77  2765196.08  2024-12-26 09:28:17.233000
#      objectid  行政區  地標類型    地標名稱                      地址           電話   網址  \
# 866       867  中和區  國民中學  市立中和國中  新北市中和區忠孝里11鄰興南路二段3巷17號  02-29424074  NaN
# 868       869  中和區  國民中學  市立漳和國中      新北市中和區枋寮里19鄰廣福路39號  02-22488616  NaN
# 867       868  中和區  國民中學  市立自強國中     新北市中和區明穗里24鄰莒光路191號  02-22259466  NaN
# 869       870  中和區  國民中學  市立積穗國中      新北市中和區嘉新里11鄰民安街66號  02-22250233  NaN
#
#        twd97_x     twd97_y                        更新日期
# 866  301339.05  2764341.98  2024-12-26 09:28:17.233000
# 868  301028.33  2766168.77  2024-12-26 09:28:17.233000
# 867  297712.66  2765720.95  2024-12-26 09:28:17.233000
# 869  298342.99  2765876.56  2024-12-26 09:28:17.233000
#      objectid  行政區  地標類型    地標名稱                        地址           電話   網址  \
# 669       670  中和區  國民小學  市立中和國小        新北市中和區漳和里3鄰中和路100號  02-22492550  NaN
# 670       671  中和區  國民小學  市立光復國小        新北市中和區中原里7鄰光環路二段1號  02-32348645  NaN
# 671       672  中和區  國民小學  市立自強國小        新北市中和區自強里3鄰莒光路200號  02-29557936  NaN
# 672       673  中和區  國民小學  市立秀山國小          新北市中和區秀山里1鄰立人街2號  02-29434353  NaN
# 673       674  中和區  國民小學  市立復興國小     新北市中和區中興里30鄰復興路301巷6號  02-22472993  NaN
# 677       678  中和區  國民小學  市立錦和國小       新北市中和區錦中里16鄰圓通路292號  02-22479495  NaN
# 674       675  中和區  國民小學  市立景新國小    新北市中和區景南里31鄰景新街467巷37號  02-29448021  NaN
# 675       676  中和區  國民小學  市立積穗國小        新北市中和區文元里1鄰員山路154號  02-22225533  NaN
# 676       677  中和區  國民小學  市立興南國小  新北市中和區忠孝里27鄰興南路一段135巷24號  02-29422349  NaN
#
#        twd97_x     twd97_y                        更新日期
# 669  300633.79  2765855.83  2024-12-26 09:28:17.233000
# 670  298705.78  2767491.83  2024-12-26 09:28:17.233000
# 671  297632.98  2765687.78  2024-12-26 09:28:17.233000
# 672  302608.81  2765238.54  2024-12-26 09:28:17.233000
# 673  300670.20  2764723.88  2024-12-26 09:28:17.233000
# 677  299421.26  2764700.43  2024-12-26 09:28:17.233000
# 674  301988.99  2764691.13  2024-12-26 09:28:17.233000
# 675  298592.74  2765758.76  2024-12-26 09:28:17.233000
# 676  301397.39  2764404.27  2024-12-26 09:28:17.233000
#      objectid  行政區  地標類型      地標名稱                        地址           電話  \
# 4           5  中和區  大專院校  私立華夏科技大學       新北市中和區華新里44鄰工專路111號  02-89415100
# 587       588  中和區   高中職    市立中和高中       新北市中和區嘉慶里14鄰連城路460號  02-22227146
# 866       867  中和區  國民中學    市立中和國中    新北市中和區忠孝里11鄰興南路二段3巷17號  02-29424074
# 868       869  中和區  國民中學    市立漳和國中        新北市中和區枋寮里19鄰廣福路39號  02-22488616
# 867       868  中和區  國民中學    市立自強國中       新北市中和區明穗里24鄰莒光路191號  02-22259466
# 869       870  中和區  國民中學    市立積穗國中        新北市中和區嘉新里11鄰民安街66號  02-22250233
# 669       670  中和區  國民小學    市立中和國小        新北市中和區漳和里3鄰中和路100號  02-22492550
# 670       671  中和區  國民小學    市立光復國小        新北市中和區中原里7鄰光環路二段1號  02-32348645
# 671       672  中和區  國民小學    市立自強國小        新北市中和區自強里3鄰莒光路200號  02-29557936
# 672       673  中和區  國民小學    市立秀山國小          新北市中和區秀山里1鄰立人街2號  02-29434353
# 673       674  中和區  國民小學    市立復興國小     新北市中和區中興里30鄰復興路301巷6號  02-22472993
# 677       678  中和區  國民小學    市立錦和國小       新北市中和區錦中里16鄰圓通路292號  02-22479495
# 674       675  中和區  國民小學    市立景新國小    新北市中和區景南里31鄰景新街467巷37號  02-29448021
# 675       676  中和區  國民小學    市立積穗國小        新北市中和區文元里1鄰員山路154號  02-22225533
# 676       677  中和區  國民小學    市立興南國小  新北市中和區忠孝里27鄰興南路一段135巷24號  02-29422349
#
#       網址    twd97_x     twd97_y                        更新日期
# 4    NaN  301259.57  2763722.47  2024-12-26 09:28:17.233000
# 587  NaN  298286.77  2765196.08  2024-12-26 09:28:17.233000
# 866  NaN  301339.05  2764341.98  2024-12-26 09:28:17.233000
# 868  NaN  301028.33  2766168.77  2024-12-26 09:28:17.233000
# 867  NaN  297712.66  2765720.95  2024-12-26 09:28:17.233000
# 869  NaN  298342.99  2765876.56  2024-12-26 09:28:17.233000
# 669  NaN  300633.79  2765855.83  2024-12-26 09:28:17.233000
# 670  NaN  298705.78  2767491.83  2024-12-26 09:28:17.233000
# 671  NaN  297632.98  2765687.78  2024-12-26 09:28:17.233000
# 672  NaN  302608.81  2765238.54  2024-12-26 09:28:17.233000
# 673  NaN  300670.20  2764723.88  2024-12-26 09:28:17.233000
# 677  NaN  299421.26  2764700.43  2024-12-26 09:28:17.233000
# 674  NaN  301988.99  2764691.13  2024-12-26 09:28:17.233000
# 675  NaN  298592.74  2765758.76  2024-12-26 09:28:17.233000
# 676  NaN  301397.39  2764404.27  2024-12-26 09:28:17.233000
#     item         name county  countycode  town  areacode  \
# 0      1       下庄公有市場    新北市       65000   八里區  65000230
# 1      2       中央公有市場    新北市       65000   三重區  65000020
# 2      3       光明公有市場    新北市       65000   三重區  65000020
# 3      4       重新公有市場    新北市       65000   三重區  65000020
# 4      5     光明公有市場2樓    新北市       65000  三重區   65000020
# 5      6      三峽公有市場     新北市       65000  三峽區   65000090
# 6      7       礁溪公有市場    新北市       65000   三峽區  65000090
# 7      8     土城公有零售市場    新北市       65000   土城區  65000130
# 8      9       頂埔公有市場    新北市       65000   土城區  65000130
# 9     10       民享公有市場    新北市       65000   中和區  65000030
# 10    11       枋寮公有市場    新北市       65000   中和區  65000030
# 11    12     和平街攤販集中區    新北市       65000   中和區  65000030
# 12    13       永安公有市場    新北市       65000   永和區  65000040
# 13    14       溪洲公有市場    新北市       65000   永和區  65000040
# 14    15       金龍公有市場    新北市       65000   汐止區  65000110
# 15    16  秀豐公有市場(攤集區)    新北市       65000   汐止區  65000110
# 16    17       中正公有市場    新北市       65000   汐止區  65000110
# 17    18       忠厚公有市場    新北市       65000   汐止區  65000110
# 18    19      林森攤販集中區    新北市       65000   汐止區  65000110
# 19    20      觀光攤販集中區    新北市       65000   汐止區  65000110
# 20    21       湳興公有市場    新北市       65000   板橋區  65000010
# 21    22   黃石公有市場(中繼)    新北市       65000   板橋區  65000010
# 22    23       後埔公有市場    新北市       65000   板橋區  65000010
# 23    24       東勢公有市場    新北市       65000   林口區  65000170
# 24    25       林口公有市場    新北市       65000   林口區  65000170
# 25    26       麗林公有市場    新北市       65000   林口區  65000170
# 26    27       第一公有市場    新北市       65000   金山區  65000270
# 27    28       泰山公有市場    新北市       65000   泰山區  65000160
# 28    29       澳底公有市場    新北市       65000   貢寮區  65000260
# 29    30     中山公有零售市場    新北市       65000   淡水區  65000100
# 30    31       中正美食廣場    新北市       65000   淡水區  65000100
# 31    32       深坑公有市場    新北市       65000   深坑區  65000180
# 32    33       中央公有市場    新北市       65000   新店區  65000060
# 33    34       碧潭公有市場    新北市       65000   新店區  65000060
# 34    35       安康公有市場    新北市       65000   新店區  65000060
# 35    36       中央公有市場    新北市       65000   新店區  65000060
# 36    37       第一公有市場    新北市       65000   新莊區  65000050
# 37    38       第一公有市場    新北市       65000   瑞芳區  65000120
# 38    39       瑞芳美食廣場    新北市       65000   瑞芳區  65000120
# 39    40      野柳攤販集中場    新北市       65000   萬里區  65000280
# 40    41       萬里公有市場    新北市       65000   萬里區  65000280
# 41    42      保安攤販集中區    新北市       65000   樹林區  65000070
# 42    43       雙溪公有市場    新北市       65000   雙溪區  65000250
# 43    44       蘆洲公有市場    新北市       65000   蘆洲區  65000140
# 44    45       永平公有市場    新北市       65000   蘆洲區  65000140
# 45    46       長安公有市場    新北市       65000   蘆洲區  65000140
# 46    47       鶯歌公有市場    新北市       65000   鶯歌區  65000080
# 47    48       鶯歌美食廣場    新北市       65000   鶯歌區  65000080
# 48    49     五股公有零售市場    新北市       65000   五股區  65000150
#
#                            address         phone    types
# 0                     新北市八里區舊城路19號  (02)26101533       早市
# 1                    新北市三重區中央北路26號  (02)29754991       早市
# 2                     新北市三重區重安街70號  (02)29772735       早市
# 3                   新北市三重區重新路87-6號  (02)29754991       早市
# 4                   新北市三重區重安街70號2樓           NaN      超市
# 5                    新北市三峽區民生街186號  (02)86721664      早市
# 6                     新北市三峽區光明路71號           NaN       超市
# 7                     新北市土城區中正路18號  (02)29410176  早市及黃昏市場
# 8                  新北市土城區中州路28巷30號           NaN       超市
# 9                     新北市中和區民享街37號  (02)22492868  早市及黃昏市場
# 10                    新北市中和區中和路74號  (02)22492868       早市
# 11                    新北市中和區和平街89號  (02)29410176     黃昏市場
# 12                   新北市永和區安樂路431號  (02)29256805       早市
# 13                  新北市永和區勵行街42-1號  (02)29256803       早市
# 14                   新北市汐止區中興路250號  (02)86933583       早市
# 15                    新北市汐止火車站臺鐵橋下  (02)86462351     黃昏市場
# 16                   新北市汐止區中正路206號  (02)86462351       早市
# 17               新北市汐止區樟樹一路137巷26號  (02)86462231       早市
# 18  汐止國道高速公路高架橋下(15K+265至15K+397)   (02)86462231       早市
# 19            新北市汐止區水源路一段至新興路之臺鐵橋下  (02)86462351       夜市
# 20                    新北市板橋區中興路63號  (02)29663624       早市
# 21                     新北市板橋區公館街1號  (02)29663624       早市
# 22                     新北市板橋區大華街5號  (02)29663624       早市
# 23                新北市林口區林口區麗園一街35號  (02)29004000       早市
# 24                    新北市林口區林口路15號  (02)26020082       早市
# 25                    新北市林口區公園路59號           NaN       超市
# 26                   新北市金山區中山路188號  (02)24926381       早市
# 27                   新北市泰山區全興路212號  (02)29004000       早市
# 28                    新北市貢寮區仁愛路79號  (02)24930205       早市
# 29                    新北市淡水區中山路77號  (02)26219669       早市
# 30                   新北市淡水區中正路115號  (02)26219669     美食廣場
# 31                  新北市深坑區平埔街22巷8號           NaN       超市
# 32                   新北市新店區中央五街60號  (02)22191865       店家
# 33                   新北市新店區新店路159號  (02)29143391       早市
# 34                 新北市新店區安康路二段120號           NaN       超市
# 35                   新北市新店區中央五街60號           NaN       超市
# 36                   新北市新莊區新莊路315號  (02)29926228       早市
# 37                   新北市瑞芳區明燈路三段2號  (02)84974251       早市
# 38                  新北市瑞芳區民生街35巷2號  (02)24974251     美食廣場
# 39               新北市萬里區野柳里港東路攤販街2號  (02)24926381      賣店區
# 40                   新北市萬里區瑪鋉路261號  (02)24926381       早市
# 41                       保安街一段14巷   (02)26846492       早市
# 42                    新北市雙溪區太平路50號  (02)24930205       早市
# 43                   新北市蘆洲區成功路160號  (02)22817273     美食廣場
# 44                     新北市蘆洲區永平街1號  (02)22817273       早市
# 45                    新北市蘆洲區長安街96號           NaN       超市
# 46             新北市鶯歌區建國路108號1樓、B1樓  (02)26780352       早市
# 47                 新北市鶯歌區建國路108號2樓  (02)26780352     美食廣場
# 48                     新北市五股區工商路3號           NaN     早、午市
#     item      name county  countycode town  areacode       address  \
# 9     10    民享公有市場    新北市       65000  中和區  65000030  新北市中和區民享街37號
# 10    11    枋寮公有市場    新北市       65000  中和區  65000030  新北市中和區中和路74號
# 11    12  和平街攤販集中區    新北市       65000  中和區  65000030  新北市中和區和平街89號
#
#            phone    types
# 9   (02)22492868  早市及黃昏市場
# 10  (02)22492868       早市
# 11  (02)29410176     黃昏市場
#   name        phone          address
# 0  好市多  02-449-9909  新北市中和區中山路二段347號
#      name        phone            address
# 0  大潤發中和店  02-82411111  新北市中和區中山路二段228號B2
# 1  大潤發景平店  02-29436000    新北市中和區景平路182號B1
#        name                      phone            address  types
# 0    家樂福中和店               02-8245-5566  新北市中和區中山路二段295號B1    量販店
# 1    家樂福景安店               02-2240-9628    新北市中和區景平路353號B1  24H超市
# 2  家樂福中和中山店               02-8221-2870    新北市中和區中山路三段1-3號  24H超市
# 3  家樂福中和民治店  02-8221-8517、02-8221-8597      新北市中和區民治街120號  24H超市
# 4  家樂福中和復興店               02-8242-3945      新北市中和區復興路268號  24H超市
# 5  家樂福中和圓通店  02-2249-8224、02-2249-7404      新北市中和區圓通路274號    量販店
# 6  家樂福中和壽德店  02-2964-3543、02-2964-3541     新北市中和區壽德街20號1樓    量販店
# 7  家樂福中和興南店             02-2948-1240~1   新北市中和區興南路一段20號B1  24H超市
#         name        phone                    address
# 0    全聯中和新生店  02-22267175          新北市中和區新生街255、257號
# 1    全聯中和秀朗店  02-29466606          新北市中和區秀朗路３段175巷2號
# 2      全聯南華店  02-22482639             新北市中和區南華路２７號Ｂ１
# 3    全聯中和光華店  02-82455860           新北市中和區光華街31巷2號1樓
# 4    全聯中和中山店  02-82267105           新北市中和區中山路３段35-2號
# 5    全聯中和景平店  02-82451916  新北市中和區景平路541號B1、543號1樓、B1
# 6    全聯中和大勇店  02-29495972               新北市中和區大勇街78號
# 7    全聯中和福祥店  02-22430586               新北市中和區福祥路72號
# 8    全聯中和民德店  02-29620320              新北市中和區民德路187號
# 9    全聯中和南山店  02-22400572          新北市中和區南山路146巷1號1樓
# 10  全聯中和南勢角店  02-29401270      新北市中和區捷運路29.31.33.35號
# 11   全聯中和華夏店  02-29401736  新北市中和區工專路26號2樓、28、30號1-2樓
# 12   全聯中和安邦店  02-22400796           新北市中和區安邦街18號1-2樓
# 13   全聯中和華新店  02-29400755   新北市中和區華新街26-1號1樓、26-2號B1
# 14   全聯中和捷運店  02-22401799          新北市中和區中山路二段269號B1
# 15   全聯中和景德店  02-29400696           新北市中和區景德街7號、9號1樓
# 16   全聯中和中正店  02-22401061             新北市中和區中正路80號1樓
# 17   全聯中和宜安店  02-22310375              新北市中和區安平路109號
# 18   全聯中和景新店  02-31518633          新北市中和區景新街516號地下2樓
# 19   全聯中和民樂店  02-22289128                新北市中和區民樂路3號
#           name        phone        address
# 0  南崁聯福利中心-民德店  02-29506251  新北市中和區民德路176號
# (35, 10)
# (35, 13)
#             name area                      address  management  \
# no
# 1    訊塘社區公園(公兒十)  八里區            新北市八里區商港路與中山路二段路口       八里區公所
# 2     南山公園 (公兒三)  八里區               新北市八里區賢三街30號對面       八里區公所
# 3      北河公園(公兒二)  八里區              新北市八里區忠孝路與忠八街路口       八里區公所
# 4      舊城公園(公兒七)  八里區             新北市八里區中山路二段303巷底       八里區公所
# 5         大崁環保公園  八里區              新北市八里區觀海大道29號對面       八里區公所
# ..           ...  ...                          ...         ...
# 658  鳳福公園(鳳鳴細兒一)  鶯歌區  新北市鶯歌區鳳福路及鳳鳴路交叉口（鳳福市民活動中心旁）       鶯歌區公所
# 659    尖福公園(公兒四)  鶯歌區                新北市鶯歌區高職東街19巷       鶯歌區公所
# 660     鶯歌國民運動中心  鶯歌區                   鶯歌區館前路250號    新北市政府體育局
# 661       十分瀑布公園  平溪區               新北市平溪區南山里乾坑10號  新北市政府觀光旅遊局
# 662         十分公園  平溪區               新北市平溪區十分街66巷1號       平溪區公所
#
#     localcall service  areacode
# no
# 1        (02)26102621  65000230
# 2        (02)26102621  65000230
# 3        (02)26102621  65000230
# 4        (02)26102621  65000230
# 5        (02)26102621  65000230
# ..                ...       ...
# 658      (02)26780202  65000080
# 659      (02)26780202  65000080
# 660      (02)26780202  65000080
# 661      (02)24958409  65000240
# 662      (02)24951510  65000240
#
# [662 rows x 6 columns]
#              name area                 address management localcall service  \
# no
# 157     清穗公園(公廿九)  中和區  華順街二巷內民德停車場後方及民德路、華順街口      中和區公所      (02)22482688
# 158     華福公園(公廿一)  中和區                華福街、和平街口      中和區公所      (02)22482688
# 159      明德公園(公七)  中和區          民德路208號及274號對面      中和區公所      (02)22482688
# 160          安邦公園  中和區                連勝街、安邦街口      中和區公所      (02)22482688
# 161      自強公園(公廿)  中和區                莒光路、國光街口      中和區公所      (02)22482688
# 162      員山公園(公八)  中和區                員山路455巷內      中和區公所      (02)22482688
# 163     嘉穗公園(公十一)  中和區                  民利街9巷內      中和區公所      (02)22482688
# 164      景新公園(公六)  中和區          景新街467巷50弄三介廟旁      中和區公所      (02)22482688
# 165     中興公園(公十二)  中和區            中興街263巷74號對面      中和區公所      (02)22482688
# 166      復興公園(公四)  中和區                復興路280巷內      中和區公所      (02)22482688
# 167      秀山公園(公七)  中和區                 自立路15巷內      中和區公所      (02)22482688
# 168      中和公園(公四)  中和區        中安街、永貞路、安樂路及安平路間      中和區公所      (02)22482688
# 169        廟美綠林小徑  中和區              中山路2段181巷旁      中和區公所      (02)22482688
# 170        金山板南公園  中和區           板南路(南山路及中興街間)      中和區公所      (02)22482688
# 171          泰隆公園  中和區                橋和路、福祥路口      中和區公所      (02)22482688
# 172        民樂人行廣場  中和區            民樂路17號中和郵局後方      中和區公所      (02)22482688
# 173        華新人行廣場  中和區               興南路2段79巷內      中和區公所      (02)22482688
# 174    民享藝文特區(公一)  中和區                民享街、民治街間      中和區公所      (02)22482688
# 175          元隆公園  中和區              立言街與板南路口附近      中和區公所      (02)22482688
# 176          壽德公園  中和區                 民德路與壽德街      中和區公所      (02)22482688
# 177          福美公園  中和區                  莊敬街49巷      中和區公所      (02)22482688
# 178       瓦窯溝沿線綠帶  中和區         勝利路至水源路127巷間水利地      中和區公所      (02)22482688
# 179      廟仔尾溝加蓋綠帶  中和區        中山路二段174巷至莊敬橋間綠帶      中和區公所      (02)22482688
# 180       南山溝加蓋綠帶  中和區         南山路到興南路二段74巷間綠帶      中和區公所      (02)22482688
# 181          圓通綠廊  中和區             連勝街至中正路間綠帶       中和區公所      (02)22482688
# 182     中和大排旁簡易公園  中和區          中山路二段322巷內簡易公園      中和區公所      (02)22482688
# 183          中坑公園  中和區             員山路及圓通路交接路口      中和區公所      (02)22482688
# 184  興南路二段261巷口綠帶  中和區              興南路二段261巷口      中和區公所      (02)22482688
# 185     華中橋四面邊坡綠帶  中和區                    華中橋下      中和區公所      (02)22482688
# 186      板南抽水站旁綠帶  中和區                 板南路中正路口      中和區公所      (02)22482688
# 187      花曆公園(公一)  中和區                   中原街旁       中和區公所      (02)22482688
# 188      樟樹公園(公二)  中和區             環河西路三段近永福宮       中和區公所      (02)22482688
# 189     光之公園(公兒一)  中和區            中原東街與中原五街之間       中和區公所      (02)22482688
# 190     風之公園(公兒二)  中和區             中原街與中原五街之間       中和區公所      (02)22482688
# 191      綠之公園(公六)  中和區            中原東街與中原六街之間       中和區公所      (02)22482688
# 192      水之公園(公七)  中和區           三段中原街與中原二街之間       中和區公所      (02)22482688
# 193          員勝公園  中和區            中正路二段與員山路交叉口      中和區公所      (02)22482688
# 194        錦和運動公園  中和區           新北市中和區錦和路350號      中和區公所      (02)22482688
#
#      areacode
# no
# 157  65000030
# 158  65000030
# 159  65000030
# 160  65000030
# 161  65000030
# 162  65000030
# 163  65000030
# 164  65000030
# 165  65000030
# 166  65000030
# 167  65000030
# 168  65000030
# 169  65000030
# 170  65000030
# 171  65000030
# 172  65000030
# 173  65000030
# 174  65000030
# 175  65000030
# 176  65000030
# 177  65000030
# 178  65000030
# 179  65000030
# 180  65000030
# 181  65000030
# 182  65000030
# 183  65000030
# 184  65000030
# 185  65000030
# 186  65000030
# 187  65000030
# 188  65000030
# 189  65000030
# 190  65000030
# 191  65000030
# 192  65000030
# 193  65000030
# 194  65000030
# (38, 6)
#      no          name area                       address management  \
# 0   157     清穗公園(公廿九)  中和區  新北市中和區華順街二巷內民德停車場後方及民德路、華順街口      中和區公所
# 1   158     華福公園(公廿一)  中和區                新北市中和區華福街、和平街口      中和區公所
# 2   159      明德公園(公七)  中和區          新北市中和區民德路208號及274號對面      中和區公所
# 3   160          安邦公園  中和區                新北市中和區連勝街、安邦街口      中和區公所
# 4   161      自強公園(公廿)  中和區                新北市中和區莒光路、國光街口      中和區公所
# 5   162      員山公園(公八)  中和區                新北市中和區員山路455巷內      中和區公所
# 6   163     嘉穗公園(公十一)  中和區                  新北市中和區民利街9巷內      中和區公所
# 7   164      景新公園(公六)  中和區          新北市中和區景新街467巷50弄三介廟旁      中和區公所
# 8   165     中興公園(公十二)  中和區            新北市中和區中興街263巷74號對面      中和區公所
# 9   166      復興公園(公四)  中和區                新北市中和區復興路280巷內      中和區公所
# 10  167      秀山公園(公七)  中和區                 新北市中和區自立路15巷內      中和區公所
# 11  168      中和公園(公四)  中和區        新北市中和區中安街、永貞路、安樂路及安平路間      中和區公所
# 12  169        廟美綠林小徑  中和區              新北市中和區中山路2段181巷旁      中和區公所
# 13  170        金山板南公園  中和區           新北市中和區板南路(南山路及中興街間)      中和區公所
# 14  171          泰隆公園  中和區                新北市中和區橋和路、福祥路口      中和區公所
# 15  172        民樂人行廣場  中和區            新北市中和區民樂路17號中和郵局後方      中和區公所
# 16  173        華新人行廣場  中和區               新北市中和區興南路2段79巷內      中和區公所
# 17  174    民享藝文特區(公一)  中和區                新北市中和區民享街、民治街間      中和區公所
# 18  175          元隆公園  中和區              新北市中和區立言街與板南路口附近      中和區公所
# 19  176          壽德公園  中和區                 新北市中和區民德路與壽德街      中和區公所
# 20  177          福美公園  中和區                  新北市中和區莊敬街49巷      中和區公所
# 21  178       瓦窯溝沿線綠帶  中和區         新北市中和區勝利路至水源路127巷間水利地      中和區公所
# 22  179      廟仔尾溝加蓋綠帶  中和區        新北市中和區中山路二段174巷至莊敬橋間綠帶      中和區公所
# 23  180       南山溝加蓋綠帶  中和區         新北市中和區南山路到興南路二段74巷間綠帶      中和區公所
# 24  181          圓通綠廊  中和區             新北市中和區連勝街至中正路間綠帶       中和區公所
# 25  182     中和大排旁簡易公園  中和區          新北市中和區中山路二段322巷內簡易公園      中和區公所
# 26  183          中坑公園  中和區             新北市中和區員山路及圓通路交接路口      中和區公所
# 27  184  興南路二段261巷口綠帶  中和區              新北市中和區興南路二段261巷口      中和區公所
# 28  185     華中橋四面邊坡綠帶  中和區                    新北市中和區華中橋下      中和區公所
# 29  186      板南抽水站旁綠帶  中和區                 新北市中和區板南路中正路口      中和區公所
# 30  187      花曆公園(公一)  中和區                   新北市中和區中原街旁       中和區公所
# 31  188      樟樹公園(公二)  中和區             新北市中和區環河西路三段近永福宮       中和區公所
# 32  189     光之公園(公兒一)  中和區            新北市中和區中原東街與中原五街之間       中和區公所
# 33  190     風之公園(公兒二)  中和區             新北市中和區中原街與中原五街之間       中和區公所
# 34  191      綠之公園(公六)  中和區            新北市中和區中原東街與中原六街之間       中和區公所
# 35  192      水之公園(公七)  中和區           新北市中和區三段中原街與中原二街之間       中和區公所
# 36  193          員勝公園  中和區            新北市中和區中正路二段與員山路交叉口      中和區公所
# 37  194        錦和運動公園  中和區           新北市中和區新北市中和區錦和路350號      中和區公所
#
#    localcall service  areacode
# 0       (02)22482688  65000030
# 1       (02)22482688  65000030
# 2       (02)22482688  65000030
# 3       (02)22482688  65000030
# 4       (02)22482688  65000030
# 5       (02)22482688  65000030
# 6       (02)22482688  65000030
# 7       (02)22482688  65000030
# 8       (02)22482688  65000030
# 9       (02)22482688  65000030
# 10      (02)22482688  65000030
# 11      (02)22482688  65000030
# 12      (02)22482688  65000030
# 13      (02)22482688  65000030
# 14      (02)22482688  65000030
# 15      (02)22482688  65000030
# 16      (02)22482688  65000030
# 17      (02)22482688  65000030
# 18      (02)22482688  65000030
# 19      (02)22482688  65000030
# 20      (02)22482688  65000030
# 21      (02)22482688  65000030
# 22      (02)22482688  65000030
# 23      (02)22482688  65000030
# 24      (02)22482688  65000030
# 25      (02)22482688  65000030
# 26      (02)22482688  65000030
# 27      (02)22482688  65000030
# 28      (02)22482688  65000030
# 29      (02)22482688  65000030
# 30      (02)22482688  65000030
# 31      (02)22482688  65000030
# 32      (02)22482688  65000030
# 33      (02)22482688  65000030
# 34      (02)22482688  65000030
# 35      (02)22482688  65000030
# 36      (02)22482688  65000030
# 37      (02)22482688  65000030
# C:\Users\chibisakura\AppData\Local\Temp\ipykernel_8728\793388477.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_park['address'] = '新北市中和區' + filtered_park['address']
