# %%
import pandas as pd

df = pd.read_csv('./data/real_estate_cleaned.csv', encoding = 'utf-8')
df
type(df)

df2 = pd.read_csv('./data/地址經緯度.csv', sep = '{', encoding = 'utf-8')
new_index = df2.reset_index(drop = True)
df2_geometry = pd.Series(new_index['geometry'])
df3 = df2_geometry.str.rstrip('}')
df3
# Out:
# 0       'lat': 24.9852149, 'lng': 121.5103486
# 1       'lat': 25.0007532, 'lng': 121.4713008
# 2       'lat': 24.9952137, 'lng': 121.5176433
# 3       'lat': 24.9939162, 'lng': 121.5048345
# 4        'lat': 24.999849, 'lng': 121.4847919
#                         ...
# 3598    'lat': 24.9909558, 'lng': 121.5082805
# 3599    'lat': 24.9909558, 'lng': 121.5082805
# 3600    'lat': 24.9909558, 'lng': 121.5082805
# 3601    'lat': 24.9909558, 'lng': 121.5082805
# 3602    'lat': 24.9909558, 'lng': 121.5082805
# Name: geometry, Length: 3603, dtype: object
